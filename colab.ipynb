# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd minigo
# Out:
# /content/minigo

# %%
# !cp ../drive/MyDrive/minigo/minigo_checkpoint.pth .

# %%
# !cp minigo_checkpoint.pth ../drive/MyDrive/minigo/minigo_checkpoint.pth

# %%
# !cp minigo.pth ../drive/MyDrive/minigo/minigo.pth

# %%
# !python accuracy.py minigo.pth ../drive/MyDrive/minigo/train.pt ../drive/MyDrive/minigo/pred.pt
# Out:
# ../drive/MyDrive/minigo/train.pt | Policy accuracy: 42.08% | Value MSE: 1.7858
# ../drive/MyDrive/minigo/pred.pt | Policy accuracy: 39.55% | Value MSE: 1.4810
